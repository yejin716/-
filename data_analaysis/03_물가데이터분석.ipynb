# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

import matplotlib as mpl 
import matplotlib.font_manager as fm 

mpl.rcParams['axes.unicode_minus'] = False
plt.rcParams['font.family'] == '맑은 고딕'
# Out:
# False

# %%
#!pip install koreanize-matplotlib
import koreanize_matplotlib

# %%
df = pd.read_csv('./data/생필품 농수축산물 가격 정보.csv', encoding='cp949')

# %%
df.head()
# Out:
#       일련번호  시장/마트 번호  시장/마트 이름  품목 번호       품목 이름   실판매규격  가격(원)     년도-월  \
# 0  1673336         2    신세계백화점    133      무(세척무)      1개   2980  2021-06
# 1  1667985       228    방배종합시장     23          상추  1봉150g   1500  2021-06
# 2  1666935         1      통인시장    266  고등어(생물,국산)     1마리   4000  2021-06
# 3  1671116        25  방학동도깨비시장    268  고등어(냉동,국산)    350g   2500  2021-06
# 4  1667066         6   이마트 용산점    171     달걀(10개)     15구   5980  2021-06
#
#         비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름        점검일자
# 0  국내산,세척무                  2              대형마트  140000     중구  2021-06-24
# 1      국내산                  1              전통시장  650000    서초구  2021-06-24
# 2   국내산,생물                  1              전통시장  110000    종로구  2021-06-24
# 3      국내산                  1              전통시장  320000    도봉구  2021-06-24
# 4   낭이생생대란                  2              대형마트  170000    용산구  2021-06-24

# %%
df.dtypes
# Out:
# 일련번호                  int64
# 시장/마트 번호              int64
# 시장/마트 이름             object
# 품목 번호                 int64
# 품목 이름                object
# 실판매규격                object
# 가격(원)                 int64
# 년도-월                 object
# 비고                   object
# 시장유형 구분(시장/마트) 코드     int64
# 시장유형 구분(시장/마트) 이름    object
# 자치구 코드                int64
# 자치구 이름               object
# 점검일자                 object
# dtype: object

# %%
df.columns
# Out:
# Index(['일련번호', '시장/마트 번호', '시장/마트 이름', '품목 번호', '품목 이름', '실판매규격', '가격(원)',
#        '년도-월', '비고', '시장유형 구분(시장/마트) 코드', '시장유형 구분(시장/마트) 이름', '자치구 코드',
#        '자치구 이름', '점검일자'],
#       dtype='object')

# %%
#데이터 확인 

#컬럼별(속성정보) 확인

df['시장/마트 번호']
# Out:
# 0          2
# 1        228
# 2          1
# 3         25
# 4          6
#         ...
# 42694    226
# 42695    226
# 42696    226
# 42697    226
# 42698    226
# Name: 시장/마트 번호, Length: 42699, dtype: int64

# %%
df['시장/마트 번호'].nunique()
#nunique : number of unique
#102개 시장/마트 존재
# Out:
# 102

# %%
df['시장/마트 이름'].nunique()
# Out:
# 102

# %%
df['시장/마트 이름'].unique()
# Out:
# array(['신세계백화점', '방배종합시장', '통인시장', '방학동도깨비시장', '이마트 용산점', '용문시장',
#        'NC백화점 불광점', '관악신사시장(신림4동)', '영천시장', '고척근린시장', '이마트 여의도점',
#        '현대백화점 미아점', '롯데백화점', '이마트 가양점', '홈플러스 동대문점', '송화시장', '영등포전통시장',
#        '홈플러스 등촌점', '후암시장', '경동시장', '롯데마트 강변점', '롯데백화점 노원점', '롯데백화점 청량리점',
#        '홈플러스 영등포점', '우림시장', '청량리종합시장', '농협 하나로마트 용산점', '이마트 자양점',
#        '롯데백화점 미아점', '자양골목시장', '수유재래시장', '홈플러스 중계점', '금남시장', '인왕시장',
#        '원당종합시장', '목3동시장', '신영시장', '이마트 왕십리점', '뉴코아아울렛 강남점', '망원시장',
#        '마천중앙시장', '신세계백화점 강남점', '롯데백화점 영등포점', '남성시장', '마포농수산물시장',
#        '이마트 창동점', '공릉동 도깨비시장', '홈플러스 면목점', '이마트 청계점', '이마트 성수점',
#        '홈플러스 방학점', '이마트 역삼점', '남구로시장', '이마트 은평점', '뚝도시장', '롯데백화점 강남점',
#        '노룬산골목시장', '현대백화점 신촌점', '홈플러스 목동점', '태평백화점', '대조시장', '남문시장',
#        '광장시장', '대림중앙시장', '남대문시장', '하나로클럽 양재점', '현대시장', '상계중앙시장',
#        '농협하나로마트 신촌점', '이마트 신도림점', '신창시장', '롯데백화점 잠실점', '이마트 목동점',
#        '홈플러스 잠실점', '대림시장', '홈플러스 시흥점', '암사종합시장', '이마트 상봉점', '숭인시장',
# ...

# %%
#시장/마트 목록
#중복 데이터 여부 확인 
#겹친다면 drop_duplicates()

df.columns
# Out:
# Index(['일련번호', '시장/마트 번호', '시장/마트 이름', '품목 번호', '품목 이름', '실판매규격', '가격(원)',
#        '년도-월', '비고', '시장유형 구분(시장/마트) 코드', '시장유형 구분(시장/마트) 이름', '자치구 코드',
#        '자치구 이름', '점검일자'],
#       dtype='object')

# %%
df[['시장/마트 번호','시장/마트 이름','자치구 이름','시장유형 구분(시장/마트) 이름']]
# Out:
#        시장/마트 번호  시장/마트 이름 자치구 이름 시장유형 구분(시장/마트) 이름
# 0             2    신세계백화점     중구              대형마트
# 1           228    방배종합시장    서초구              전통시장
# 2             1      통인시장    종로구              전통시장
# 3            25  방학동도깨비시장    도봉구              전통시장
# 4             6   이마트 용산점    용산구              대형마트
# ...         ...       ...    ...               ...
# 42694       226  롯데마트 구로점    구로구              대형마트
# 42695       226  롯데마트 구로점    구로구              대형마트
# 42696       226  롯데마트 구로점    구로구              대형마트
# 42697       226  롯데마트 구로점    구로구              대형마트
# 42698       226  롯데마트 구로점    구로구              대형마트
#
# [42699 rows x 4 columns]

# %%
df_market = df[['시장/마트 번호','시장/마트 이름','자치구 이름','시장유형 구분(시장/마트) 이름']].drop_duplicates()

# %%
#자치구별 시장/마트 개수 
df_market.head()
# Out:
#    시장/마트 번호  시장/마트 이름 자치구 이름 시장유형 구분(시장/마트) 이름
# 0         2    신세계백화점     중구              대형마트
# 1       228    방배종합시장    서초구              전통시장
# 2         1      통인시장    종로구              전통시장
# 3        25  방학동도깨비시장    도봉구              전통시장
# 4         6   이마트 용산점    용산구              대형마트

# %%
df_market['자치구 이름']
# Out:
# 0         중구
# 1        서초구
# 2        종로구
# 3        도봉구
# 4        용산구
#         ...
# 5339     중랑구
# 5341     강북구
# 6609     구로구
# 21043    도봉구
# 42682    구로구
# Name: 자치구 이름, Length: 102, dtype: object

# %%
df_market['자치구 이름'].value_counts()
# Out:
# 자치구 이름
# 중구      6
# 도봉구     5
# 관악구     5
# 구로구     5
# 영등포구    5
# 노원구     4
# 금천구     4
# 강남구     4
# 송파구     4
# 마포구     4
# 양천구     4
# 성동구     4
# 강북구     4
# 중랑구     4
# 동대문구    4
# 광진구     4
# 서초구     4
# 강서구     4
# 성북구     4
# 서대문구    4
# 은평구     4
# 용산구     4
# 강동구     4
# 동작구     2
# 종로구     2
# Name: count, dtype: int64

# %%
df_market['자치구 이름'] == '관악구'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 5339     False
# 5341     False
# 6609     False
# 21043    False
# 42682    False
# Name: 자치구 이름, Length: 102, dtype: bool

# %%
condition = df_market['자치구 이름'] == '관악구'
df_market[condition]
# Out:
#       시장/마트 번호      시장/마트 이름 자치구 이름 시장유형 구분(시장/마트) 이름
# 9          207  관악신사시장(신림4동)    관악구              전통시장
# 125        133        원당종합시장    관악구              전통시장
# 2221       134    신원시장(신림1동)    관악구              전통시장
# 3203       135     롯데백화점 관악점    관악구              대형마트
# 3344       136        세이브 마트    관악구              대형마트

# %%
condition = df_market['자치구 이름'] == '구로구'
df_market[condition]
# Out:
#        시장/마트 번호    시장/마트 이름 자치구 이름 시장유형 구분(시장/마트) 이름
# 15          109      고척근린시장    구로구              전통시장
# 298         108       남구로시장    구로구              전통시장
# 766         110    이마트 신도림점    구로구              대형마트
# 6609        227  NC백화점 신구로점    구로구              대형마트
# 42682       226    롯데마트 구로점    구로구              대형마트

# %%
#품목 목록 

df[['품목 번호','품목 이름']]
# Out:
#        품목 번호       품목 이름
# 0        133      무(세척무)
# 1         23          상추
# 2        266  고등어(생물,국산)
# 3        268  고등어(냉동,국산)
# 4        171     달걀(10개)
# ...      ...         ...
# 42694    171     달걀(10개)
# 42695     27           배
# 42696    312         애호박
# 42697     22          오이
# 42698    302          명태
#
# [42699 rows x 2 columns]

# %%
df[['품목 번호','품목 이름']].drop_duplicates()
# Out:
#        품목 번호         품목 이름
# 0        133        무(세척무)
# 1         23            상추
# 2        266    고등어(생물,국산)
# 3        268    고등어(냉동,국산)
# 4        171       달걀(10개)
# ...      ...           ...
# 5348     135    조기(중국산,생물)
# 6813     257   오징어(냉동,수입산)
# 15781    316  고등어(30cm,국산)
# 18573    134        달걀(왕란)
# 19167    263     명태(냉동,국산)
#
# [81 rows x 2 columns]

# %%
df_items = df[['품목 번호','품목 이름']].drop_duplicates()

# %%
df_items.sort_values('품목 이름')
# Out:
#        품목 번호          품목 이름
# 222       13            고등어
# 135      304            고등어
# 15781    316   고등어(30cm,국산)
# 1550     318  고등어(30cm,수입산)
# 3        268     고등어(냉동,국산)
# ...      ...            ...
# 1397     261     조기(생물,수입산)
# 5348     135     조기(중국산,생물)
# 649      277             호박
# 18       119      호박(인큐베이터)
# 1898     118   호박(인큐베이터),중간
#
# [81 rows x 2 columns]

# %%
df_items = df_items.sort_values('품목 이름')

# %%
#품목 이름 확인 (30개씩 확인)

df_items[:30]
# Out:
#        품목 번호           품목 이름
# 222       13             고등어
# 135      304             고등어
# 15781    316    고등어(30cm,국산)
# 1550     318   고등어(30cm,수입산)
# 3        268      고등어(냉동,국산)
# 4834     269     고등어(냉동,수입산)
# 2        266      고등어(생물,국산)
# 1341     267     고등어(생물,수입산)
# 3984     314  냉동참조기(20cm,국산)
# 3706     313  냉동참조기(20cm,수입)
# 768       17              달걀
# 4        171         달걀(10개)
# 860      321         달걀(15개)
# 11       320         달걀(30개)
# 18573    134          달걀(왕란)
# 5280     181          달걀(왕란)
# 45        18             닭고기
# 16       283         닭고기(육계)
# 583      275         닭고기(중간)
# 487      138        닭고기(토종닭)
# 226      288              동태
# 53       285            돼지고기
# 1501      52       돼지고기(삼겹살)
# 34        99      돼지고기(생삼겹살)
# 22       202      돼지고기(생삼겹살)
# 23       302              명태
# 555      315    명태(45cm,수입산)
# 19167    263       명태(냉동,국산)
# 54       264      명태(냉동,수입산)
# 32       152      명태(러시아,냉동)

# %%
df_items[30:60]
# Out:
#       품목 번호         품목 이름
# 2457    265    명태(생물,수입산)
# 1019    184    명태(일본산,냉동)
# 79       25             무
# 103     308        무(1kg)
# 0       133        무(세척무)
# 33      282        무(세척무)
# 2432    274     무(세척무, 중)
# 157      27             배
# 56      276         배(신고)
# 4268    248   배(신고),중급(대)
# 14      306   배(신고, 600g)
# 1820    284         배(중품)
# 15       26            배추
# 9       307   배추(2.5~3kg)
# 1529    125        배추(국산)
# 2466    175        배추(중간)
# 1159    271        배추(중간)
# 58       28            사과
# 446      50        사과(부사)
# 4802    237  사과(부사),중급(대)
# 4556    244  사과(부사),중급(대)
# 12      305  사과(부사, 300g)
# 1        23            상추
# 35      310      상추(100g)
# 97      278           쇠고기
# 533      82   쇠고기(육우,불고기)
# 8        58   쇠고기(한우,불고기)
# 339     131    쇠고기(한우1등급)
# 6       312           애호박
# 7        24            양파

# %%
df_items[60:]
# Out:
#       품목 번호         품목 이름
# 10      309    양파(1.5kg망)
# 2191    272       양파(작은망)
# 5        22            오이
# 21      311       오이(다다기)
# 31      253           오징어
# 2620     54       오징어(냉동)
# 441     256    오징어(냉동,국산)
# 6813    257   오징어(냉동,수입산)
# 36      254    오징어(생물,국산)
# 2567    255   오징어(생물,수입산)
# 19      303            조기
# 389     144     조기(국산,냉동)
# 30      136     조기(국산,생물)
# 114     259     조기(냉동,국산)
# 177     260    조기(냉동,수입산)
# 1479    258     조기(생물,국산)
# 1397    261    조기(생물,수입산)
# 5348    135    조기(중국산,생물)
# 649     277            호박
# 18      119     호박(인큐베이터)
# 1898    118  호박(인큐베이터),중간

# %%
#자치구 목록 
df.columns
# Out:
# Index(['일련번호', '시장/마트 번호', '시장/마트 이름', '품목 번호', '품목 이름', '실판매규격', '가격(원)',
#        '년도-월', '비고', '시장유형 구분(시장/마트) 코드', '시장유형 구분(시장/마트) 이름', '자치구 코드',
#        '자치구 이름', '점검일자'],
#       dtype='object')

# %%
df[['자치구 코드','자치구 이름']].drop_duplicates()
# Out:
#       자치구 코드 자치구 이름
# 0     140000     중구
# 1     650000    서초구
# 2     110000    종로구
# 3     320000    도봉구
# 4     170000    용산구
# 7     380000    은평구
# 9     620000    관악구
# 13    410000   서대문구
# 15    530000    구로구
# 17    560000   영등포구
# 18    290000    성북구
# 25    500000    강서구
# 27    230000   동대문구
# 43    215000    광진구
# 47    350000    노원구
# 63    260000    중랑구
# 99    305000    강북구
# 113   200000    성동구
# 131   470000    양천구
# 199   440000    마포구
# 209   710000    송파구
# 235   590000    동작구
# 296   680000    강남구
# 531   545000    금천구
# 1573  740000    강동구

# %%
df_gu = df[['자치구 코드','자치구 이름']].drop_duplicates()

df_gu.shape
# Out:
# (25, 2)

# %%
#시장 유형 

df[['시장유형 구분(시장/마트) 코드', '시장유형 구분(시장/마트) 이름']]
# Out:
#        시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름
# 0                      2              대형마트
# 1                      1              전통시장
# 2                      1              전통시장
# 3                      1              전통시장
# 4                      2              대형마트
# ...                  ...               ...
# 42694                  2              대형마트
# 42695                  2              대형마트
# 42696                  2              대형마트
# 42697                  2              대형마트
# 42698                  2              대형마트
#
# [42699 rows x 2 columns]

# %%
df_gubun = df[['시장유형 구분(시장/마트) 코드', '시장유형 구분(시장/마트) 이름']].drop_duplicates()

# %%
#품목별 

df[df['품목 이름'].str.contains('삼겹살')]
# Out:
#           일련번호  시장/마트 번호    시장/마트 이름  품목 번호       품목 이름               실판매규격  \
# 22     1668431        16   현대백화점 미아점    202  돼지고기(생삼겹살)  600g (100g 4,280원)
# 34     1667081        10        용문시장     99  돼지고기(생삼겹살)               100g
# 47     1670116        98   롯데백화점 노원점     99  돼지고기(생삼겹살)                600g
# 76     1674090        42     이마트 가양점     99  돼지고기(생삼겹살)                600g
# 86     1668834        42     이마트 가양점     99  돼지고기(생삼겹살)                600g
# ...        ...       ...         ...    ...         ...                 ...
# 42403  1636726        55        광장시장     99  돼지고기(생삼겹살)                600g
# 42432  1633340        86   홈플러스 동대문점    202  돼지고기(생삼겹살)                100g
# 42477  1633986       127        남성시장     99  돼지고기(생삼겹살)                600g
# 42486  1631638        88  롯데백화점 청량리점    202  돼지고기(생삼겹살)                100g
# 42665  1636353       154    홈플러스 강동점     52   돼지고기(삼겹살)                600g
#
# ...

# %%
#품목이 삼겹살이고 년도-월이 2021-06인 행 
condition = (df['품목 이름'].str.contains('삼겹살')) & (df['년도-월'] == '2021-06')

# %%
df[condition]
# Out:
#          일련번호  시장/마트 번호   시장/마트 이름  품목 번호       품목 이름               실판매규격  \
# 22    1668431        16  현대백화점 미아점    202  돼지고기(생삼겹살)  600g (100g 4,280원)
# 34    1667081        10       용문시장     99  돼지고기(생삼겹살)               100g
# 47    1670116        98  롯데백화점 노원점     99  돼지고기(생삼겹살)                600g
# 76    1674090        42    이마트 가양점     99  돼지고기(생삼겹살)                600g
# 86    1668834        42    이마트 가양점     99  돼지고기(생삼겹살)                600g
# ...       ...       ...        ...    ...         ...                 ...
# 6698  1673495        10       용문시장     99  돼지고기(생삼겹살)               100g
# 6700  1671992        16  현대백화점 미아점    202  돼지고기(생삼겹살)  600g (100g 4,280원)
# 6720  1670803        10       용문시장     99  돼지고기(생삼겹살)               100g
# 6721  1670048        16  현대백화점 미아점    202  돼지고기(생삼겹살)  600g (100g 4,280원)
# 6763  1674900        16  현대백화점 미아점    202  돼지고기(생삼겹살)  600g (100g 4,280원)
#
#       가격(원)     년도-월        비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드  \
# ...

# %%
#품목이 삼겹살이고 년도-월이 2021-06이고 실판매규격이 600g인 행 

condition = (df['품목 이름'].str.contains('삼겹살')) & (df['년도-월'] == '2021-06') & (df['실판매규격'].str.contains('600g'))

# %%
df_sam = df[condition]

# %%
#삼겹살 600g의 평균 가격은?
df_sam['가격(원)'].mean()
# Out:
# 16842.723214285714

# %%
#가장 비싼 곳은 어딜까

df_sam[df_sam['가격(원)'] == 35890]
# Out:
#          일련번호  시장/마트 번호   시장/마트 이름  품목 번호       품목 이름 실판매규격  가격(원)     년도-월  \
# 4043  1668108       147  롯데백화점 잠실점     99  돼지고기(생삼겹살)  600g  35890  2021-06
# 4064  1674531       147  롯데백화점 잠실점     99  돼지고기(생삼겹살)  600g  35890  2021-06
#
#        비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름        점검일자
# 4043  국내산                  2              대형마트  710000    송파구  2021-06-24
# 4064  NaN                  2              대형마트  710000    송파구  2021-06-24

# %%
#가장 싼 곳은 어딜까

df_sam[df_sam['가격(원)'] == 1690]
# Out:
#          일련번호  시장/마트 번호  시장/마트 이름  품목 번호       품목 이름 실판매규격  가격(원)     년도-월  \
# 4052  1667438        28  홈플러스 방학점     99  돼지고기(생삼겹살)  600g   1690  2021-06
#
#        비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름        점검일자
# 4052  국내산                  2              대형마트  320000    도봉구  2021-06-24

# %%
df_sam[df_sam['가격(원)'] < 5000]
# Out:
#          일련번호  시장/마트 번호  시장/마트 이름  품목 번호       품목 이름 실판매규격  가격(원)     년도-월  \
# 3645  1667404        27   이마트 창동점     99  돼지고기(생삼겹살)  600g   2720  2021-06
# 4052  1667438        28  홈플러스 방학점     99  돼지고기(생삼겹살)  600g   1690  2021-06
#
#        비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름        점검일자
# 3645  국내산                  2              대형마트  320000    도봉구  2021-06-24
# 4052  국내산                  2              대형마트  320000    도봉구  2021-06-24

# %% [markdown]
# 우리 동네 삼겹살 가격?

# %%
gu = input('당신이 사는 구 이름은?')

# %%
gu
# Out:
# '도봉구'

# %%
condition = df_sam['자치구 이름'] == gu

# %%
df_sam[condition]
# Out:
#          일련번호  시장/마트 번호  시장/마트 이름  품목 번호       품목 이름 실판매규격  가격(원)     년도-월  \
# 2689  1670184        25  방학동도깨비시장     99  돼지고기(생삼겹살)  600g  13800  2021-06
# 2698  1671109        25  방학동도깨비시장     99  돼지고기(생삼겹살)  600g  12000  2021-06
# 2719  1673750        25  방학동도깨비시장     99  돼지고기(생삼겹살)  600g  12000  2021-06
# 2741  1667387        25  방학동도깨비시장     99  돼지고기(생삼겹살)  600g  12000  2021-06
# 3100  1667421        26      신창시장     99  돼지고기(생삼겹살)  600g  13980  2021-06
# 3188  1671143        26      신창시장     99  돼지고기(생삼겹살)  600g  15180  2021-06
# 3196  1673784        26      신창시장     99  돼지고기(생삼겹살)  600g  15180  2021-06
# 3205  1670218        26      신창시장     99  돼지고기(생삼겹살)  600g  12500  2021-06
# 3593  1673767        27   이마트 창동점     99  돼지고기(생삼겹살)  600g  14100  2021-06
# 3603  1670201        27   이마트 창동점     99  돼지고기(생삼겹살)  600g  18600  2021-06
# 3645  1667404        27   이마트 창동점     99  돼지고기(생삼겹살)  600g   2720  2021-06
# ...

# %%
df_sam.columns
# Out:
# Index(['일련번호', '시장/마트 번호', '시장/마트 이름', '품목 번호', '품목 이름', '실판매규격', '가격(원)',
#        '년도-월', '비고', '시장유형 구분(시장/마트) 코드', '시장유형 구분(시장/마트) 이름', '자치구 코드',
#        '자치구 이름', '점검일자'],
#       dtype='object')

# %%
df_sam[condition][['시장/마트 이름', '품목 이름','실판매규격', '가격(원)']]
# Out:
#       시장/마트 이름       품목 이름 실판매규격  가격(원)
# 2689  방학동도깨비시장  돼지고기(생삼겹살)  600g  13800
# 2698  방학동도깨비시장  돼지고기(생삼겹살)  600g  12000
# 2719  방학동도깨비시장  돼지고기(생삼겹살)  600g  12000
# 2741  방학동도깨비시장  돼지고기(생삼겹살)  600g  12000
# 3100      신창시장  돼지고기(생삼겹살)  600g  13980
# 3188      신창시장  돼지고기(생삼겹살)  600g  15180
# 3196      신창시장  돼지고기(생삼겹살)  600g  15180
# 3205      신창시장  돼지고기(생삼겹살)  600g  12500
# 3593   이마트 창동점  돼지고기(생삼겹살)  600g  14100
# 3603   이마트 창동점  돼지고기(생삼겹살)  600g  18600
# 3645   이마트 창동점  돼지고기(생삼겹살)  600g   2720
# 3680   이마트 창동점  돼지고기(생삼겹살)  600g  14100
# 3979  홈플러스 방학점  돼지고기(생삼겹살)  600g  12140
# 4024  홈플러스 방학점  돼지고기(생삼겹살)  600g  22140
# 4052  홈플러스 방학점  돼지고기(생삼겹살)  600g   1690
# 4094  홈플러스 방학점  돼지고기(생삼겹살)  600g  12420

# %%
df_sam_gu = df_sam[condition][['시장/마트 이름', '품목 이름','실판매규격', '가격(원)']]
df_sam_gu
# Out:
#       시장/마트 이름       품목 이름 실판매규격  가격(원)
# 2689  방학동도깨비시장  돼지고기(생삼겹살)  600g  13800
# 2698  방학동도깨비시장  돼지고기(생삼겹살)  600g  12000
# 2719  방학동도깨비시장  돼지고기(생삼겹살)  600g  12000
# 2741  방학동도깨비시장  돼지고기(생삼겹살)  600g  12000
# 3100      신창시장  돼지고기(생삼겹살)  600g  13980
# 3188      신창시장  돼지고기(생삼겹살)  600g  15180
# 3196      신창시장  돼지고기(생삼겹살)  600g  15180
# 3205      신창시장  돼지고기(생삼겹살)  600g  12500
# 3593   이마트 창동점  돼지고기(생삼겹살)  600g  14100
# 3603   이마트 창동점  돼지고기(생삼겹살)  600g  18600
# 3645   이마트 창동점  돼지고기(생삼겹살)  600g   2720
# 3680   이마트 창동점  돼지고기(생삼겹살)  600g  14100
# 3979  홈플러스 방학점  돼지고기(생삼겹살)  600g  12140
# 4024  홈플러스 방학점  돼지고기(생삼겹살)  600g  22140
# 4052  홈플러스 방학점  돼지고기(생삼겹살)  600g   1690
# 4094  홈플러스 방학점  돼지고기(생삼겹살)  600g  12420

# %%
#데이터 시각화 

x = df_sam_gu['시장/마트 이름']
y = df_sam_gu['가격(원)']

plt.scatter(x,y)
plt.title(gu + ' 삼겹살 가격 현황')
plt.grid()
plt.show()

# %% [markdown]
# #마트 지점별 삼겹살 가격

# %%
mart = input('시장/마트 이름: ')

# %%
#마트 지점별 삼겹살 가격 

df_sam['시장/마트 이름']
# Out:
# 22      현대백화점 미아점
# 47      롯데백화점 노원점
# 76        이마트 가양점
# 86        이마트 가양점
# 146       이마트 가양점
#           ...
# 6439     홈플러스 중계점
# 6514     홈플러스 등촌점
# 6700    현대백화점 미아점
# 6721    현대백화점 미아점
# 6763    현대백화점 미아점
# Name: 시장/마트 이름, Length: 224, dtype: object

# %%
df_sam_mart = df_sam[df_sam['시장/마트 이름'].str.contains(mart)]

# %%
df_sam_mart.columns
# Out:
# Index(['일련번호', '시장/마트 번호', '시장/마트 이름', '품목 번호', '품목 이름', '실판매규격', '가격(원)',
#        '년도-월', '비고', '시장유형 구분(시장/마트) 코드', '시장유형 구분(시장/마트) 이름', '자치구 코드',
#        '자치구 이름', '점검일자'],
#       dtype='object')

# %%
df_sam_mart[['시장/마트 이름','품목 번호', '품목 이름', '실판매규격', '가격(원)']]
# Out:
#       시장/마트 이름  품목 번호       품목 이름               실판매규격  가격(원)
# 76     이마트 가양점     99  돼지고기(생삼겹살)                600g  15480
# 86     이마트 가양점     99  돼지고기(생삼겹살)                600g  14880
# 146    이마트 가양점     99  돼지고기(생삼겹살)                600g  14880
# 325    이마트 성수점    202  돼지고기(생삼겹살)                600g  15480
# 459    이마트 자양점     99  돼지고기(생삼겹살)                600g  14880
# 745    이마트 자양점     99  돼지고기(생삼겹살)                600g  22080
# 1021   이마트 가양점     99  돼지고기(생삼겹살)                600g  14100
# 3436  이마트 왕십리점    202  돼지고기(생삼겹살)                600g  14880
# 3461  이마트 왕십리점    202  돼지고기(생삼겹살)                600g  15480
# 3477  이마트 왕십리점    202  돼지고기(생삼겹살)                600g  14100
# 3486  이마트 왕십리점    202  돼지고기(생삼겹살)                600g  14880
# 3593   이마트 창동점     99  돼지고기(생삼겹살)                600g  14100
# 3603   이마트 창동점     99  돼지고기(생삼겹살)                600g  18600
# 3632   이마트 성수점    202  돼지고기(생삼겹살)                600g  14100
# ...

# %%
len(df_sam_mart[['시장/마트 이름','품목 번호', '품목 이름', '실판매규격', '가격(원)']])
# Out:
# 28

# %%
#데이터 시각화 

x = df_sam_mart['시장/마트 이름']
y = df_sam_mart['가격(원)']

plt.scatter(x,y)
plt.title(mart + ' 삼겹살 가격 현황')
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %%
#in-class Practice

#미션 : 달걀 가격 분석해 보세요 
#조건 : 포함 되어야 할 문자 : 달걀, 30개(실판매규격)

# %%
df_egg = df[df['품목 이름'].str.contains('달걀')].drop_duplicates()

# %%
df_egg
# Out:
#           일련번호  시장/마트 번호   시장/마트 이름  품목 번호    품목 이름       실판매규격  가격(원)  \
# 4      1667066         6    이마트 용산점    171  달걀(10개)         15구   5980
# 11     1671112        25   방학동도깨비시장    320  달걀(30개)       1.8kg   9500
# 26     1668433        16  현대백화점 미아점    171  달걀(10개)         10개   6000
# 28     1668434        16  현대백화점 미아점    320  달걀(30개)         30개      0
# 43     1670908        82   롯데마트 강변점    320  달걀(30개)         30개  10800
# ...        ...       ...        ...    ...      ...         ...    ...
# 42666  1633869        40   홈플러스 등촌점    171  달걀(10개)   10개(600g)   3490
# 42674  1633904       109     고척근린시장    320  달걀(30개)     특란1800g   5000
# 42679  1632325       109     고척근린시장    320  달걀(30개)  30개(1.5kg)   5000
# 42686  1636119       226   롯데마트 구로점    320  달걀(30개)  30개(1.8kg)   6990
# 42694  1636118       226   롯데마트 구로점    171  달걀(10개)   10개(600g)   2990
#
#           년도-월       비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름  \
# ...

# %%
df_egg[df_egg['가격(원)'] == 0]
# Out:
#           일련번호  시장/마트 번호    시장/마트 이름  품목 번호    품목 이름    실판매규격  가격(원)     년도-월  \
# 28     1668434        16   현대백화점 미아점    320  달걀(30개)      30개      0  2021-06
# 1139   1671027        88  롯데백화점 청량리점    320  달걀(30개)      30개      0  2021-06
# 3953   1671893       147   롯데백화점 잠실점    320  달걀(30개)      30개      0  2021-06
# 3982   1669551       147   롯데백화점 잠실점    320  달걀(30개)      30개      0  2021-06
# 4049   1668111       147   롯데백화점 잠실점    320  달걀(30개)      30개      0  2021-06
# ...        ...       ...         ...    ...      ...      ...    ...      ...
# 40003  1635295       135   롯데백화점 관악점    320  달걀(30개)      30개      0  2021-01
# 40203  1631641        88  롯데백화점 청량리점    320  달걀(30개)  30개(대란)      0  2021-01
# 41873  1637871       147   롯데백화점 잠실점    320  달걀(30개)      30개      0  2021-01
# 42236  1635635        88  롯데백화점 청량리점    320  달걀(30개)  30개(대란)      0  2021-01
# 42395  1635142       147   롯데백화점 잠실점    320  달걀(30개)     30r개      0  2021-01
#
# ...

# %%
df_egg = df_egg[df_egg['가격(원)'] != 0]

# %%
df_egg
# Out:
#           일련번호  시장/마트 번호   시장/마트 이름  품목 번호    품목 이름       실판매규격  가격(원)  \
# 4      1667066         6    이마트 용산점    171  달걀(10개)         15구   5980
# 11     1671112        25   방학동도깨비시장    320  달걀(30개)       1.8kg   9500
# 26     1668433        16  현대백화점 미아점    171  달걀(10개)         10개   6000
# 43     1670908        82   롯데마트 강변점    320  달걀(30개)         30개  10800
# 52     1667084        10       용문시장    320  달걀(30개)         30개  10500
# ...        ...       ...        ...    ...      ...         ...    ...
# 42666  1633869        40   홈플러스 등촌점    171  달걀(10개)   10개(600g)   3490
# 42674  1633904       109     고척근린시장    320  달걀(30개)     특란1800g   5000
# 42679  1632325       109     고척근린시장    320  달걀(30개)  30개(1.5kg)   5000
# 42686  1636119       226   롯데마트 구로점    320  달걀(30개)  30개(1.8kg)   6990
# 42694  1636118       226   롯데마트 구로점    171  달걀(10개)   10개(600g)   2990
#
#           년도-월       비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름  \
# ...

# %%
df_egg['가격(원)'].max() #최대 가격
# Out:
# 75000

# %%
df_egg['가격(원)'].min() #최소 가격
# Out:
# 200

# %%
df_egg[df_egg['가격(원)'] == 75000]
# Out:
#         일련번호  시장/마트 번호 시장/마트 이름  품목 번호    품목 이름       실판매규격  가격(원)     년도-월  \
# 414  1669381       108    남구로시장    320  달걀(30개)  30개(1.5kg)  75000  2021-06
#
#          비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름        점검일자
# 414  국내산,특란                  1              전통시장  530000    구로구  2021-06-24

# %%
df_egg[df_egg['가격(원)'] == 200]
# Out:
#           일련번호  시장/마트 번호 시장/마트 이름  품목 번호    품목 이름 실판매규격  가격(원)     년도-월  비고  \
# 38081  1632934       114     현대시장    171  달걀(10개)   10개    200  2021-01  국산
#
#        시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름        점검일자
# 38081                  1              전통시장  545000    금천구  2021-01-28

# %%
df_egg_30 = df_egg[df_egg['실판매규격'].str.contains('30')]

# %%
df_egg_30.head()
# Out:
#        일련번호  시장/마트 번호  시장/마트 이름  품목 번호    품목 이름       실판매규격  가격(원)     년도-월  \
# 43  1670908        82  롯데마트 강변점    320  달걀(30개)         30개  10800  2021-06
# 52  1667084        10      용문시장    320  달걀(30개)         30개  10500  2021-06
# 62  1671401        42   이마트 가양점    320  달걀(30개)  30개(1800g)   6900  2021-06
# 75  1667237        82  롯데마트 강변점    320  달걀(30개)         30개  10800  2021-06
# 82  1674093        42   이마트 가양점    320  달걀(30개)  30개(1800g)   6900  2021-06
#
#          비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름        점검일자
# 43  1등급란.특란                  2              대형마트  215000    광진구  2021-06-24
# 52    건강영양란                  1              전통시장  170000    용산구  2021-06-24
# 62   국내산,특란                  2              대형마트  500000    강서구  2021-06-24
# 75  1등급란.특란                  2              대형마트  215000    광진구  2021-06-24
# 82   국내산,특란                  2              대형마트  500000    강서구  2021-06-24

# %%
#데이터 시각화 

x = df_egg_30['자치구 이름']
y = df_egg_30['가격(원)']

plt.scatter(x,y)
plt.title(' 삼겹살 가격 현황')
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %% [markdown]
# 강사님 풀이

# %%
df[df['가격(원)'] < 0]
# Out:
# Empty DataFrame
# Columns: [일련번호, 시장/마트 번호, 시장/마트 이름, 품목 번호, 품목 이름, 실판매규격, 가격(원), 년도-월, 비고, 시장유형 구분(시장/마트) 코드, 시장유형 구분(시장/마트) 이름, 자치구 코드, 자치구 이름, 점검일자]
# Index: []

# %%
condition = (df['품목 이름'].str.contains('달걀')) & (df['실판매규격'].str.contains('30'))

# %%
df[condition]
# Out:
#           일련번호  시장/마트 번호   시장/마트 이름  품목 번호    품목 이름           실판매규격  가격(원)  \
# 28     1668434        16  현대백화점 미아점    320  달걀(30개)             30개      0
# 43     1670908        82   롯데마트 강변점    320  달걀(30개)             30개  10800
# 52     1667084        10       용문시장    320  달걀(30개)             30개  10500
# 62     1671401        42    이마트 가양점    320  달걀(30개)      30개(1800g)   6900
# 75     1667237        82   롯데마트 강변점    320  달걀(30개)             30개  10800
# ...        ...       ...        ...    ...      ...             ...    ...
# 42610  1635261       136     세이브 마트    320  달걀(30개)             30개   6980
# 42636  1634174        45  롯데백화점 강남점    320  달걀(30개)             30개  15000
# 42650  1633700       220       롯데슈퍼    320  달걀(30개)  30개(대란 1,560g)   5990
# 42679  1632325       109     고척근린시장    320  달걀(30개)      30개(1.5kg)   5000
# 42686  1636119       226   롯데마트 구로점    320  달걀(30개)      30개(1.8kg)   6990
#
# ...

# %%
condition = (df['품목 이름'].str.contains('달걀')) & (df['실판매규격'].str.contains('30')) & (df['가격(원)'] > 0)

# %%
df[condition]
# Out:
#           일련번호  시장/마트 번호   시장/마트 이름  품목 번호    품목 이름           실판매규격  가격(원)  \
# 43     1670908        82   롯데마트 강변점    320  달걀(30개)             30개  10800
# 52     1667084        10       용문시장    320  달걀(30개)             30개  10500
# 62     1671401        42    이마트 가양점    320  달걀(30개)      30개(1800g)   6900
# 75     1667237        82   롯데마트 강변점    320  달걀(30개)             30개  10800
# 82     1674093        42    이마트 가양점    320  달걀(30개)      30개(1800g)   6900
# ...        ...       ...        ...    ...      ...             ...    ...
# 42610  1635261       136     세이브 마트    320  달걀(30개)             30개   6980
# 42636  1634174        45  롯데백화점 강남점    320  달걀(30개)             30개  15000
# 42650  1633700       220       롯데슈퍼    320  달걀(30개)  30개(대란 1,560g)   5990
# 42679  1632325       109     고척근린시장    320  달걀(30개)      30개(1.5kg)   5000
# 42686  1636119       226   롯데마트 구로점    320  달걀(30개)      30개(1.8kg)   6990
#
# ...

# %%
df_egg = df[condition]

# %%
df_egg['가격(원)'].max()
# Out:
# 75000

# %%
df_egg['가격(원)'].min()
# Out:
# 800

# %% [markdown]
# 우리 동네 달걀

# %%
gu = input('당신이 사는 구는?')

# %%
gu
# Out:
# '강남구'

# %%
df_egg.columns
# Out:
# Index(['일련번호', '시장/마트 번호', '시장/마트 이름', '품목 번호', '품목 이름', '실판매규격', '가격(원)',
#        '년도-월', '비고', '시장유형 구분(시장/마트) 코드', '시장유형 구분(시장/마트) 이름', '자치구 코드',
#        '자치구 이름', '점검일자'],
#       dtype='object')

# %%
df_egg_gu =df_egg[df_egg['자치구 이름'] == gu][['시장/마트 이름', '품목 번호', '품목 이름', '실판매규격', '가격(원)']]

# %%
df_egg_gu= df_egg_gu.sort_values('가격(원)')

# %%
#시각화 

x = df_egg_gu['시장/마트 이름']
y = df_egg_gu['가격(원)']

plt.scatter(x,y)
plt.title(gu + ' 달걀 가격 현황')
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %%
#마트 지점별 달걀 가격 

mart = input('마트 이름: ')

# %%
mart
# Out:
# '이마트'

# %%
df_egg_mart = df_egg[df_egg['시장/마트 이름'].str.contains(mart)][['시장/마트 이름', '품목 번호', '품목 이름', '실판매규격', '가격(원)']].drop_duplicates()

# %%
df_egg_mart
# Out:
#        시장/마트 이름  품목 번호    품목 이름       실판매규격  가격(원)
# 62      이마트 가양점    320  달걀(30개)  30개(1800g)   6900
# 436     이마트 역삼점    320  달걀(30개)         30개  12360
# 506     이마트 역삼점    320  달걀(30개)         30갸  11560
# 542     이마트 역삼점    320  달걀(30개)         30개   7980
# 858    이마트 신도림점     17       달걀  25개(1300g)   7980
# ...         ...    ...      ...         ...    ...
# 41481  이마트 왕십리점    320  달걀(30개)         30개  65800
# 41484  이마트 왕십리점    320  달걀(30개)         30개   7580
# 41494   이마트 가양점    320  달걀(30개)  30개(1800g)   5980
# 41971   이마트 창동점    320  달걀(30개)  30개(1.8kg)   6980
# 42292   이마트 은평점    320  달걀(30개)  30개(1800g)   5980
#
# [133 rows x 5 columns]

# %%
df_egg_mart = df_egg_mart.sort_values('가격(원)')

# %%
x = df_egg_mart['시장/마트 이름']
y = df_egg_mart['가격(원)']

plt.scatter(x,y)
plt.title(mart + ' 달걀(30개) 가격 현황')
plt.xticks(rotation= 45)
plt.grid()
plt.show()

# %%
#추가 분석 
df_egg_mart['실판매규격']
# Out:
# 9484             30구
# 30207            30개
# 15235        30개(특란)
# 1477             30개
# 42292     30개(1800g)
#             ...
# 3627             30개
# 506              30갸
# 436              30개
# 2283     30개(1.56kg)
# 41481            30개
# Name: 실판매규격, Length: 133, dtype: object

# %%
df_egg_mart['실판매규격'].unique()
# Out:
# array(['30구', '30개', '30개(특란)', '30개(1800g)', '30개(1.8kg)',
#        '30개 (1,800g)', '30개((1.8kg)', '30개(1,800g)', '대란1830g', '30개 ',
#        '30개 1.8kg', '30개(1,560g)', '30', '30개(1560g)', '30구(25구)',
#        '25개(1300g)', '30개 (1,800원)', '30개(1.68kg)', '30갸', '30개(1.56kg)'],
#       dtype=object)
